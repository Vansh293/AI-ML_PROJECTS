# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Data_Sciencs_And_AI_ML\AI-ML-PROJECT\Finance_Project\insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1337 non-null   int64
#  1   sex       1337 non-null   object
#  2   bmi       1337 non-null   float64
#  3   children  1337 non-null   int64
#  4   smoker    1337 non-null   object
#  5   region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %%
unq_sex = df['sex'].unique()
unq_sex

dict_sex = {
        'female':1, 
        'male':2
}
df['sex'] = df['sex'].map(dict_sex)

# %%
unq_region = df['region'].unique()
unq_region

dict_region = {
    'southwest':1, 'southeast':2, 'northwest':3, 'northeast':4
}
df['region'] = df['region'].map(dict_region)

# %%
unq_smoker = df['smoker'].unique()
unq_smoker

dict_smoker = {
    'yes':1, 'no':2
}

df['smoker'] = df['smoker'].map(dict_smoker)

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       1  16884.92400
# 1      18    2  33.770         1       2       2   1725.55230
# 2      28    2  33.000         3       2       2   4449.46200
# 3      33    2  22.705         0       2       3  21984.47061
# 4      32    2  28.880         0       2       3   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    2  30.970         3       2       3  10600.54830
# 1334   18    1  31.920         0       2       4   2205.98080
# 1335   18    1  36.850         0       2       2   1629.83350
# 1336   21    1  25.800         0       2       1   2007.94500
# 1337   61    1  29.070         0       1       3  29141.36030
#
# [1337 rows x 7 columns]

# %% [markdown]
# ### ENCODED SUCCESSFULLY NOW TRAIN THE MODEL
# ---

# %%
x = df.drop(['charges'],axis=1) # independent Variable (Input)
y = df['charges']

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       1
# 1      18    2  33.770         1       2       2
# 2      28    2  33.000         3       2       2
# 3      33    2  22.705         0       2       3
# 4      32    2  28.880         0       2       3
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    2  30.970         3       2       3
# 1334   18    1  31.920         0       2       4
# 1335   18    1  36.850         0       2       2
# 1336   21    1  25.800         0       2       1
# 1337   61    1  29.070         0       1       3
#
# [1337 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### HERE WE PREDICT THE VALUES SO THAT USE RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=42)

model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
print("The Train Score Is: ",model.score(x_train,y_train))
print("The Test Score Is: ",model.score(x_test,y_test))
# Out:
# The Train Score Is:  0.9736837535934051
# The Test Score Is:  0.8808271641009859

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([10309.155615 ,  6117.3995133, 12425.3745526, 41959.1386424,
#         5793.0906476, 10175.0222939, 38447.4486648,  2098.438796 ,
#         7900.4971723, 10432.6856785, 14524.405127 , 23849.2530672,
#        42456.7472082, 15350.271642 ,  6980.2622197,  8732.2804828,
#         7047.8923905, 39541.1618852,  4188.0022594,  4985.0530344,
#         3683.2085528, 21092.9163499,  9848.4529126, 20429.7335829,
#        38328.4068728, 17817.4556455, 43189.6723222, 45816.8603455,
#        10953.721798 , 15843.5314022,  4401.2613083,  9574.5030838,
#         2061.8697971, 14676.9632177, 47316.2164902,  9772.4758151,
#         7584.1957544,  5147.882731 , 22864.9840341,  9553.2199589,
#         3165.281708 , 21224.2555634, 41742.9968077,  9661.8432109,
#         9124.3173066,  3424.0477548,  3424.337889 ,  7832.7032847,
#         6340.5438025, 12182.6923096,  4725.5357101, 11008.7982049,
#        23098.5587814,  5776.221544 ,  7181.124535 ,  8328.076133 ,
# ...

# %%
import joblib
joblib.dump(model, 'model.joblib')
# Out:
# ['model.joblib']
